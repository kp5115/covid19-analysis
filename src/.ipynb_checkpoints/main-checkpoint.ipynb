# %% [markdown]
# Main entry for analyzing covid-19 dataset.

# %%
! apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
! pip3 install pyspark
# Out:
# openjdk version "1.8.0_242"
# OpenJDK Runtime Environment (build 1.8.0_242-8u242-b08-0ubuntu3~18.04-b08)
# OpenJDK 64-Bit Server VM (build 25.242-b08, mixed mode)
# Requirement already satisfied: pyspark in /usr/local/lib/python3.6/dist-packages (2.4.5)
# Requirement already satisfied: py4j==0.10.7 in /usr/local/lib/python3.6/dist-packages (from pyspark) (0.10.7)

# %%
import sys
import logging

import pyspark

# Update path
sys.path.append("/content/drive/My Drive/Colab/")
import covid_data
import covid_plot

# %%
df = covid_data.get_global_info()
df.show()
# Out:
# +--------------------+
# |              Global|
# +--------------------+
# |[53041, 3583, 401...|
# +--------------------+

# %%
covid_plot.plot_country_status("India")
# Out:
# Recent 20 data in India
#    Country                  Date  Confirmed  Active  Deaths  Recovered
# 73   India  2020-04-12T00:00:00Z       9205    7794     331       1080
# 74   India  2020-04-13T00:00:00Z      10453    8914     358       1181
# 75   India  2020-04-14T00:00:00Z      11487    9735     393       1359
# 76   India  2020-04-15T00:00:00Z      12322   10485     405       1432
# 77   India  2020-04-16T00:00:00Z      13430   11214     448       1768
# 78   India  2020-04-17T00:00:00Z      14352   11825     486       2041
# 79   India  2020-04-18T00:00:00Z      15722   12738     521       2463
# 80   India  2020-04-19T00:00:00Z      17615   14202     559       2854
# 81   India  2020-04-20T00:00:00Z      18539   14674     592       3273
# 82   India  2020-04-21T00:00:00Z      20080   15460     645       3975
# 83   India  2020-04-22T00:00:00Z      21370   16319     681       4370
# 84   India  2020-04-23T00:00:00Z      23077   17344     721       5012
# 85   India  2020-04-24T00:00:00Z      24530   18252     780       5498
# 86   India  2020-04-25T00:00:00Z      26283   19519     825       5939
# 87   India  2020-04-26T00:00:00Z      27890   20486     881       6523
# 88   India  2020-04-27T00:00:00Z      29451   21375     939       7137
# 89   India  2020-04-28T00:00:00Z      31324   22569    1008       7747
# 90   India  2020-04-29T00:00:00Z      33062   23546    1079       8437
# 91   India  2020-04-30T00:00:00Z      34863   24641    1154       9068
# 92   India  2020-05-01T00:00:00Z      37257   26027    1223      10007
# Plot

# %%
covid_plot.plot_country_status_timebased("India", "2020-04-01", "2020-04-15")
# Out:
# Recent 20 data in India
#    Country                  Date  Confirmed  Active  Deaths  Recovered
# 0    India  2020-04-01T00:00:00Z       1998    1792      58        148
# 1    India  2020-04-02T00:00:00Z       2543    2280      72        191
# 2    India  2020-04-03T00:00:00Z       2567    2303      72        192
# 3    India  2020-04-04T00:00:00Z       3082    2767      86        229
# 4    India  2020-04-05T00:00:00Z       3588    3260      99        229
# 5    India  2020-04-06T00:00:00Z       4778    4267     136        375
# 6    India  2020-04-07T00:00:00Z       5311    4740     150        421
# 7    India  2020-04-08T00:00:00Z       5916    5232     178        506
# 8    India  2020-04-09T00:00:00Z       6725    5879     226        620
# 9    India  2020-04-10T00:00:00Z       7598    6578     246        774
# 10   India  2020-04-11T00:00:00Z       8446    7189     288        969
# 11   India  2020-04-12T00:00:00Z       9205    7794     331       1080
# 12   India  2020-04-13T00:00:00Z      10453    8914     358       1181
# 13   India  2020-04-14T00:00:00Z      11487    9735     393       1359
# Plot

# %%
covid_plot.print_world_status()
# Out:
# +--------------------+
# |              Global|
# +--------------------+
# |[53041, 3583, 401...|
# +--------------------+

# %%
covid_plot.print_world_status_timebased("2020-04-24", "2020-04-25")
# Out:
#    NewConfirmed  NewDeaths  NewRecovered
# 0         85357       7827         28791

# %%
covid_plot.plot_world_status()
# Out:
#          Country                  Date  Confirmed  Active  Deaths  Recovered
# 358510  Zimbabwe  2020-04-13T00:00:00Z         17      14       3          0
# 358511  Zimbabwe  2020-04-14T00:00:00Z         17      14       3          0
# 358512  Zimbabwe  2020-04-15T00:00:00Z         23      19       3          1
# 358513  Zimbabwe  2020-04-16T00:00:00Z         23      19       3          1
# 358514  Zimbabwe  2020-04-17T00:00:00Z         24      19       3          2
# 358515  Zimbabwe  2020-04-18T00:00:00Z         25      20       3          2
# 358516  Zimbabwe  2020-04-19T00:00:00Z         25      20       3          2
# 358517  Zimbabwe  2020-04-20T00:00:00Z         25      20       3          2
# 358518  Zimbabwe  2020-04-21T00:00:00Z         28      23       3          2
# 358519  Zimbabwe  2020-04-22T00:00:00Z         28      22       4          2
# 358520  Zimbabwe  2020-04-23T00:00:00Z         28      22       4          2
# 358521  Zimbabwe  2020-04-24T00:00:00Z         29      23       4          2
# 358522  Zimbabwe  2020-04-25T00:00:00Z         31      25       4          2
# 358523  Zimbabwe  2020-04-26T00:00:00Z         31      25       4          2
# 358524  Zimbabwe  2020-04-27T00:00:00Z         32      23       4          5
# 358525  Zimbabwe  2020-04-28T00:00:00Z         32      23       4          5
# 358526  Zimbabwe  2020-04-29T00:00:00Z         32      23       4          5
# 358527  Zimbabwe  2020-04-30T00:00:00Z         40      31       4          5
# 358528  Zimbabwe  2020-05-01T00:00:00Z         40      31       4          5
# 358529  Zimbabwe  2020-05-02T00:00:00Z         34      25       4          5
# Plot

# %%
covid_plot.plot_top_countries_totalconfirmed()
# Out:
# Table
#           Country  TotalConfirmed
# 0           Spain          216582
# 1           Italy          209328
# 2  United Kingdom          182260
# 3          France          166976
# 4         Germany          164967
# Plot

# %%
covid_plot.plot_top_countries_totalrecovered()
# Out:
# Table
#                      Country  TotalRecovered
# 0   United States of America          175382
# 1                    Germany          129000
# 2                      Spain          117248
# 3                      Italy           79914
# 4  Iran, Islamic Republic of           77350
# Plot

# %%
covid_plot.plot_top_countries_recover_rate()
# Out:
# Table
#              Country  RecoverRate  TotalRecovered  TotalConfirmed
# 0           Cambodia     0.983607             120             122
# 1            Iceland     0.948832            1706            1798
# 2          Mauritius     0.945783             314             332
# 3           Thailand     0.921106            2732            2966
# 4  Brunei Darussalam     0.913043             126             138
# Plot

# %%
covid_plot.plot_top_countries_deaths_rate()
# Out:
# Table
#           Country  DeathsRate  TotalDeaths  TotalConfirmed
# 0       Nicaragua    0.214286            3              14
# 1           Yemen    0.200000            2              10
# 2         Belgium    0.156815         7765           49517
# 3  United Kingdom    0.154345        28131          182260
# 4          France    0.148099        24729          166976
# Plot

# %%
covid_plot.plot_countries_less_recover_rate(10)
# Out:
# Table
#              Country  RecoverRate  TotalRecovered  TotalConfirmed
# 0            Comoros     0.000000               0               3
# 1     United Kingdom     0.000000               0          182260
# 2   Papua New Guinea     0.000000               0               8
# 3        South Sudan     0.000000               0              45
# 4        Netherlands     0.000000               0           40236
# 5         Tajikistan     0.000000               0              76
# 6             Norway     0.004098              32            7809
# 7         Bangladesh     0.020137             177            8790
# 8  Equatorial Guinea     0.028571               9             315
# 9           Maldives     0.034682              18             519
# Plot

# %%
covid_plot.plot_top_countries_less_deaths_rate()
# Out:
# Table
#     Country  DeathsRate  TotalDeaths  TotalConfirmed
# 0   Grenada         0.0            0              21
# 1      Fiji         0.0            0              18
# 2  Dominica         0.0            0              16
# 3    Bhutan         0.0            0               7
# 4   Eritrea         0.0            0              39
# Plot

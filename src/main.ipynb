# %% [markdown]
# Main entry for analyzing covid-19 dataset.

# %%
! apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
! pip3 install pyspark
# Out:
# openjdk version "1.8.0_242"
# OpenJDK Runtime Environment (build 1.8.0_242-8u242-b08-0ubuntu3~18.04-b08)
# OpenJDK 64-Bit Server VM (build 25.242-b08, mixed mode)
# ...

# %%
import sys
import logging

import pyspark

sys.path.append("/content/drive/My Drive/Colab/")
import covid_data

# %%
df = covid_data.get_global_info()
df.show()
# Out:
# https://api.covid19api.com/summary
# +--------------------+
# |              Global|
# +--------------------+
# |[86217, 5480, 629...|
# +--------------------+

# %%
df = covid_data.get_country_info("India")
pdf = df.toPandas()
pdf.set_index('date',inplace=True)
import pandas
lines = pdf.plot(kind="line", x="Date", y="Confirmed", x_compat=True)
#lines = pdf.plot()
import matplotlib.pyplot as plt
#plt.figure(); pdf.plot(style='k--', label='Series'); plt.legend(loc='best')
# Out:
# https://api.covid19api.com/dayone/country/India
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-6897722f53ec> in <module>()
#       1 df = covid_data.get_country_info("India")
#       2 pdf = df.toPandas()
# ----> 3 pdf.set_index('date',inplace=True)
#       4 import pandas
#       5 lines = pdf.plot(kind="line", x="Date", y="Confirmed", x_compat=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['date'] are in the columns"
